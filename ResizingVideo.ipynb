# %% [markdown]
# <a href="https://colab.research.google.com/github/arjunarora1201/Resizing-Video/blob/main/ResizingVideo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow
import os

# %%
uploaded = files.upload()
input_video_name = list(uploaded.keys())[0]
input_path = f"/content/{input_video_name}"
# Out:
#      <input type="file" id="files-643e4186-a9d8-455f-8eb9-7a761c1ff7af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-643e4186-a9d8-455f-8eb9-7a761c1ff7af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def resize_video(input_path, output_path, scale_percent=50):
    cap = cv2.VideoCapture(input_path)

    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    new_width = int(width * scale_percent/100)
    new_height = int(height * scale_percent/100)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (new_width, new_height))

    print(f"Original size: {width}x{height}")
    print(f"Resizing to: {new_width}x{new_height} ({scale_percent}%)")
    print(f"Processing {total_frames} frames...")

    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break
        resized_frame = cv2.resize(frame, (new_width, new_height),
                               interpolation=cv2.INTER_AREA)

        out.write(resized_frame)

        frame_count += 1
        if frame_count % 100 == 0:
            print(f"Processed {frame_count}/{total_frames} frames")

    cap.release()
    out.release()
    print("Resizing complete!")

# %%
output_path = "/content/resized_video.mp4"
resize_video(input_path, output_path, scale_percent=50)
# Out:
# Original size: 1920x1036
# Resizing to: 960x518 (50%)
# Processing 781 frames...
# Processed 100/781 frames
# Processed 200/781 frames
# Processed 300/781 frames
# Processed 400/781 frames
# Processed 500/781 frames
# Processed 600/781 frames
# Processed 700/781 frames
# Resizing complete!
